# %%
import os
import pandas as pd
import re
import json
import pdfplumber
from bs4 import BeautifulSoup

# %%
# Function to get all text from a PDF file
def get_pdf_text(filepath):
    text = ""
    try:
        with pdfplumber.open(filepath) as pdf:
            for page in pdf.pages:
                content = page.extract_text()
                if content:
                    text += content + "\n"
    except Exception as error:
        print(f"Could not read {filepath}: {error}")
    return text

# %%
# Function to get all text from an HTML file
def get_html_text(filepath):
    try:
        with open(filepath, "r", encoding="utf-8") as file:
            html_content = file.read()
            soup = BeautifulSoup(html_content, "html.parser")
            return soup.get_text(separator=" ")
    except Exception as error:
        print(f"Could not read {filepath}: {error}")
        return ""

# %%
# Function to find RFP information within extracted text
def find_rfp_info(text):
    result = {}
    result["Bid Number"] = match_or_blank(r"(JA-\d{6}|BPM\d+|E20P\d+)", text)
    result["Title"] = match_or_blank(r"(Student and Staff Computing Devices|Dell Laptops.*Warranty)", text)
    result["Due Date"] = match_or_blank(r"\d{2}/\d{2}/\d{4}", text)
    result["Bid Submission Type"] = match_or_blank(r"(BidNet|iSupplier|eMaryland Marketplace)", text)
    result["Term of Bid"] = match_or_blank(r"\d+\s*year|\d+\s*month", text)
    result["Pre Bid Meeting"] = match_or_blank(r"(Pre[- ]?Bid Meeting.*\d{4})", text)
    result["Installation"] = match_or_blank(r"(installation|white glove deployment|asset tagging)", text)
    result["Bid Bond Requirement"] = match_or_blank(r"(bond requirement|small business reserve)", text)
    result["Delivery Date"] = match_or_blank(r"delivery.*\d{4}|\d+\s*days.*award", text)
    result["Payment Terms"] = match_or_blank(r"net\s*\d+", text)
    result["Any Additional Documentation Required"] = match_or_blank(r"(addendum|mwbe forms|affidavit|W9|authorization)", text)
    result["MFG for Registration"] = match_or_blank(r"(manufacturer registration|Dell|vendor registration)", text)
    result["Contract or Cooperative to use"] = match_or_blank(r"(contract.*\d+|cooperative.*agreement|EPCNT|CTPA)", text)
    result["Model_no"] = match_or_blank(r"(Latitude\s*\d+|WD22TB4|SI CC\d+)", text)
    result["Part_no"] = match_or_blank(r"(SI CC\d+|WD22TB4)", text)
    result["Product"] = match_or_blank(r"(student laptops|Chromebooks|Dell Latitude.*Dock|Laptop)", text)
    result["contact_info"] = match_or_blank(r"[\w\.-]+@[\w\.-]+", text)
    result["company_name"] = match_or_blank(r"(Dallas Independent School District|State of Maryland)", text)
    result["Bid Summary"] = match_or_blank(r"(RFP.*devices|laptop refresh.*employees)", text)
    result["Product Specification"] = match_or_blank(r"(Chromebook|Windows|Apple|Latitude 5550|Dock|copilot ready|extended warranty)", text)
    return result

# %%
# Small helper so blank values never show up as None
def match_or_blank(pattern, text):
    match = re.search(pattern, text, re.IGNORECASE)
    return match.group(0).strip() if match else ""

# %%
# Main function: scan a folder, extract each file's info
def scan_rfp_folder(folder_path):
    output = []
    for filename in os.listdir(folder_path):
        filepath = os.path.join(folder_path, filename)
        if filename.lower().endswith(".pdf"):
            text = get_pdf_text(filepath)
        elif filename.lower().endswith(".html"):
            text = get_html_text(filepath)
        else:
            continue
        info = find_rfp_info(text)
        info["Source File"] = filename
        output.append(info)
    return output

# %%
# Main Extraction of the Assignment
if __name__ == "__main__":
    folder = "./rfp_docs"
    results = scan_rfp_folder(folder)
    with open("structured_output.json", "w", encoding="utf-8") as f:
        json.dump(results, f, indent=4)
    print("Extraction finished. See 'structured_output.json' for results.")
# Out:
# Extraction finished. See 'structured_output.json' for results.

# %%
# Open the saved JSON file and load the data
with open("structured_output.json", "r", encoding="utf-8") as file:
    records = json.load(file)

# %%
# Print the loaded data in an easy-to-read way
print(json.dumps(records, indent=4))
# Out:
# [
#     {
#         "Bid Number": "JA-207652",
#         "Title": "Student and Staff Computing Devices",
#         "Due Date": "",
#         "Bid Submission Type": "",
#         "Term of Bid": "3 year",
#         "Pre Bid Meeting": "",
#         "Installation": "installation",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "ADDENDUM",
#         "MFG for Registration": "",
#         "Contract or Cooperative to use": "",
#         "Model_no": "",
#         "Part_no": "",
#         "Product": "Laptop",
#         "contact_info": "",
#         "company_name": "",
#         "Bid Summary": "RFP JA-207652 Student and Staff Computing Devices",
#         "Product Specification": "Chromebook",
#         "Source File": "Addendum 1 RFP JA-207652 Student and Staff Computing Devices.pdf"
#     },
#     {
#         "Bid Number": "JA-207652",
#         "Title": "Student and Staff Computing Devices",
#         "Due Date": "",
#         "Bid Submission Type": "",
#         "Term of Bid": "",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "ADDENDUM",
#         "MFG for Registration": "",
#         "Contract or Cooperative to use": "",
#         "Model_no": "",
#         "Part_no": "",
#         "Product": "",
#         "contact_info": "",
#         "company_name": "",
#         "Bid Summary": "RFP JA-207652 Student and Staff Computing Devices",
#         "Product Specification": "",
#         "Source File": "Addendum 2 RFP JA-207652 Student and Staff Computing Devices.pdf"
#     },
#     {
#         "Bid Number": "",
#         "Title": "",
#         "Due Date": "",
#         "Bid Submission Type": "",
#         "Term of Bid": "24 month",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "affidavit",
#         "MFG for Registration": "",
#         "Contract or Cooperative to use": "contract term, on or before: (i) May 31, to cover the six (6",
#         "Model_no": "",
#         "Part_no": "",
#         "Product": "",
#         "contact_info": "",
#         "company_name": "State of Maryland",
#         "Bid Summary": "",
#         "Product Specification": "",
#         "Source File": "Contract_Affidavit.pdf"
#     },
#     {
#         "Bid Number": "BPM044557",
#         "Title": "Dell Laptops w/Extended Warranty",
#         "Due Date": "05/28/2024",
#         "Bid Submission Type": "BidNet",
#         "Term of Bid": "",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "Addendum",
#         "MFG for Registration": "Dell",
#         "Contract or Cooperative to use": "",
#         "Model_no": "Latitude 5550",
#         "Part_no": "WD22TB4",
#         "Product": "Laptop",
#         "contact_info": "Thawkins@treasurer.state.md.us",
#         "company_name": "State of Maryland",
#         "Bid Summary": "",
#         "Product Specification": "Extended Warranty",
#         "Source File": "Dell Laptops w_Extended Warranty - Bid Information - {3} _ BidNet Direct.html"
#     },
#     {
#         "Bid Number": "",
#         "Title": "",
#         "Due Date": "",
#         "Bid Submission Type": "",
#         "Term of Bid": "",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "",
#         "MFG for Registration": "Dell",
#         "Contract or Cooperative to use": "",
#         "Model_no": "Latitude 5550",
#         "Part_no": "",
#         "Product": "",
#         "contact_info": "Tax_Department@dell.com",
#         "company_name": "",
#         "Bid Summary": "",
#         "Product Specification": "Latitude 5550",
#         "Source File": "Dell_Laptop_Specs.pdf"
#     },
#     {
#         "Bid Number": "JA-207652",
#         "Title": "Student and Staff Computing Devices",
#         "Due Date": "",
#         "Bid Submission Type": "iSupplier",
#         "Term of Bid": "5 year",
#         "Pre Bid Meeting": "",
#         "Installation": "installation",
#         "Bid Bond Requirement": "bond requirement",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "addendum",
#         "MFG for Registration": "",
#         "Contract or Cooperative to use": "contractor 1",
#         "Model_no": "",
#         "Part_no": "",
#         "Product": "laptop",
#         "contact_info": "JALZATE@dallasisd.org",
#         "company_name": "Dallas Independent School District",
#         "Bid Summary": "RFP) will be for student and staff computing devices",
#         "Product Specification": "Chromebook",
#         "Source File": "JA-207652 Student and Staff Computing Devices FINAL.pdf"
#     },
#     {
#         "Bid Number": "",
#         "Title": "",
#         "Due Date": "",
#         "Bid Submission Type": "",
#         "Term of Bid": "",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "AFFIDAVIT",
#         "MFG for Registration": "",
#         "Contract or Cooperative to use": "contract, and (3",
#         "Model_no": "",
#         "Part_no": "",
#         "Product": "",
#         "contact_info": "",
#         "company_name": "State of Maryland",
#         "Bid Summary": "",
#         "Product Specification": "",
#         "Source File": "Mercury_Affidavit.pdf"
#     },
#     {
#         "Bid Number": "E20P4600040",
#         "Title": "",
#         "Due Date": "05/24/2024",
#         "Bid Submission Type": "eMaryland Marketplace",
#         "Term of Bid": "3 year",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "SMALL BUSINESS RESERVE",
#         "Delivery Date": "45 days of Award",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "Authorization",
#         "MFG for Registration": "Dell",
#         "Contract or Cooperative to use": "",
#         "Model_no": "Latitude 5550",
#         "Part_no": "WD22TB4",
#         "Product": "Laptop",
#         "contact_info": "thawkins@treasurer.state.md.us",
#         "company_name": "",
#         "Bid Summary": "",
#         "Product Specification": "Extended Warranty",
#         "Source File": "PORFP_-_Dell_Laptop_Final.pdf"
#     },
#     {
#         "Bid Number": "JA-207652",
#         "Title": "Student and Staff Computing Devices",
#         "Due Date": "05/29/2024",
#         "Bid Submission Type": "BidNet",
#         "Term of Bid": "",
#         "Pre Bid Meeting": "",
#         "Installation": "",
#         "Bid Bond Requirement": "",
#         "Delivery Date": "",
#         "Payment Terms": "",
#         "Any Additional Documentation Required": "Addendum",
#         "MFG for Registration": "",
#         "Contract or Cooperative to use": "",
#         "Model_no": "",
#         "Part_no": "",
#         "Product": "laptop",
#         "contact_info": "ProcurementCS@dallasisd.org",
#         "company_name": "Dallas Independent School District",
#         "Bid Summary": "RFP) will be for student and staff computing devices, including laptops, desktops, tablet devices, and display monitors. Vendors participating in this Request for Proposal (RFP) may submit proposals for one, several, or all categories of devices required by the District. Within each category of device, the District reserves the right to award contracts to a single vendor or multiple vendors. The specifications listed in this RFP are the minimum hardware requirements for each tier of device required by Dallas ISD. Vendors responding to this RFP must have the ability to provide the District with significant quantities of devices as requested in the pricing lines in this RFP. Note that quantities requested by Dallas ISD are estimates to be ordered over the five years of the contracts resulting from this RFP. Purchases may also include a variety of device accessories which will be ordered in a bundle along with the devices. Such accessories include, but are not limited to, sleeves, cases, mice, keyboards, and cables that may not necessarily come with the devices",
#         "Product Specification": "",
#         "Source File": "Student and Staff Computing Devices __SOURCING #168884__ - Bid Information - {3} _ BidNet Direct.html"
#     }
# ]

# %%
# Display full contents elegantly
pd.DataFrame(records)
# Out:
#     Bid Number                                Title    Due Date  \
# 0    JA-207652  Student and Staff Computing Devices
# 1    JA-207652  Student and Staff Computing Devices
# 2
# 3    BPM044557     Dell Laptops w/Extended Warranty  05/28/2024
# 4
# 5    JA-207652  Student and Staff Computing Devices
# 6
# 7  E20P4600040                                       05/24/2024
# 8    JA-207652  Student and Staff Computing Devices  05/29/2024
#
#      Bid Submission Type Term of Bid Pre Bid Meeting  Installation  \
# 0                             3 year                  installation
# 1
# 2                           24 month
# 3                 BidNet
# 4
# 5              iSupplier      5 year                  installation
# 6
# 7  eMaryland Marketplace      3 year
# 8                 BidNet
#
#      Bid Bond Requirement     Delivery Date Payment Terms  ...  \
# 0                                                          ...
# 1                                                          ...
# 2                                                          ...
# 3                                                          ...
# 4                                                          ...
# 5        bond requirement                                  ...
# 6                                                          ...
# 7  SMALL BUSINESS RESERVE  45 days of Award                ...
# 8                                                          ...
#
#   MFG for Registration                     Contract or Cooperative to use  \
# 0
# 1
# 2                       contract term, on or before: (i) May 31, to co...
# 3                 Dell
# 4                 Dell
# 5                                                            contractor 1
# 6                                                        contract, and (3
# 7                 Dell
# 8
#
#         Model_no  Part_no Product                    contact_info  \
# 0                          Laptop
# 1
# 2
# 3  Latitude 5550  WD22TB4  Laptop  Thawkins@treasurer.state.md.us
# 4  Latitude 5550                          Tax_Department@dell.com
# 5                          laptop           JALZATE@dallasisd.org
# 6
# 7  Latitude 5550  WD22TB4  Laptop  thawkins@treasurer.state.md.us
# 8                          laptop     ProcurementCS@dallasisd.org
#
#                          company_name  \
# 0
# 1
# 2                   State of Maryland
# 3                   State of Maryland
# 4
# 5  Dallas Independent School District
# 6                   State of Maryland
# 7
# 8  Dallas Independent School District
#
#                                          Bid Summary Product Specification  \
# 0  RFP JA-207652 Student and Staff Computing Devices            Chromebook
# 1  RFP JA-207652 Student and Staff Computing Devices
# 2
# 3                                                        Extended Warranty
# 4                                                            Latitude 5550
# 5  RFP) will be for student and staff computing d...            Chromebook
# 6
# 7                                                        Extended Warranty
# 8  RFP) will be for student and staff computing d...
#
#                                          Source File
# 0  Addendum 1 RFP JA-207652 Student and Staff Com...
# 1  Addendum 2 RFP JA-207652 Student and Staff Com...
# 2                             Contract_Affidavit.pdf
# 3  Dell Laptops w_Extended Warranty - Bid Informa...
# 4                              Dell_Laptop_Specs.pdf
# 5  JA-207652 Student and Staff Computing Devices ...
# 6                              Mercury_Affidavit.pdf
# 7                      PORFP_-_Dell_Laptop_Final.pdf
# 8  Student and Staff Computing Devices __SOURCING...
#
# [9 rows x 21 columns]

# %%
# COMPLETED
